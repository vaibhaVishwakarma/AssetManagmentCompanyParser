# %%
import pandas as pd 
df = pd.read_csv(r"reference\SchemeData0111251523SS.csv")
df
# Out:
#                                                AMC    Code  \
# 0                Aditya Birla Sun Life AMC Limited  100033
# 1                Aditya Birla Sun Life AMC Limited  100034
# 2                Aditya Birla Sun Life AMC Limited  119433
# 3                Aditya Birla Sun Life AMC Limited  119436
# 4                Aditya Birla Sun Life AMC Limited  100037
# ...                                            ...     ...
# 16104  Old Bridge Asset Management Private Limited  153981
# 16105  Old Bridge Asset Management Private Limited  153976
# 16106  Old Bridge Asset Management Private Limited  153977
# 16107  Old Bridge Asset Management Private Limited  153978
# 16108  Old Bridge Asset Management Private Limited  153979
#
#                                       Scheme Name Scheme Type  \
# 0      Aditya Birla Sun Life Large & Mid Cap Fund  Open Ended
# 1      Aditya Birla Sun Life Large & Mid Cap Fund  Open Ended
# 2      Aditya Birla Sun Life Large & Mid Cap Fund  Open Ended
# ...

# %%
prt = pd.read_csv("Portfolio_extracted_091125-0251.csv")
prt
# Out:
#                                       Name of Instrument          ISIN  \
# 0                       Embassy Office Parks REIT EOPR01  INE041025011
# 1                             Capital Infra Trust MEBP01  INE0Z8Z23013
# 2                    Brookfield India Real Estate Trust   INE0FDU25010
# 3                         Mindspace Business Parks REIT   INE0CCU25019
# 4      6.4% Jamnagar Utilities & Power Private Limite...  INE936D07174
# ...                                                  ...           ...
# 53473  ** 08.60 % SANSAR JAN 2025 TRUST - 25/10/2028 ^^   INE1WMT15017
# 53474  ** 08.20 % INDIA UNIVERSAL TRUST AL1 - 20/09/2...  INE16J715035
# 53475  ** 08.85 % SANSAR JUNE 2024 TRUST - 25/08/2027...  INE0YWN15017
# 53476  ** 08.17 % INDIA UNIVERSAL TRUST AL2 - 21/11/2...  INE1CBK15037
# 53477               SBIMF AIF - CAT I (CDMDF)27/10/2038   INF0RQ622028
#
#        Coupon        Industry      Quantity  Market Value  % to Net Assets  \
# ...

# %%
prt.astype(str).assign(**{"temp" :prt["Scheme Name"].apply(lambda x : x.split("-")[0].strip())})

# %%
import re
isin_pattern = r"[A-Z]{3}[A-Z0-9]{8}"
t = (
    prt.merge(
        df.astype(str).groupby("Scheme Name").agg({
                "ISIN Div Payout/ ISIN GrowthISIN Div Reinvestment": ", ".join,
                "Code": ",".join
            }).reset_index()
            .assign(
            **{
                "ISIN Div Payout/ ISIN GrowthISIN Div Reinvestment": 
                    lambda x: x["ISIN Div Payout/ ISIN GrowthISIN Div Reinvestment"]
                                .apply(lambda s: ",".join(re.findall(isin_pattern, s)))
            }
        ),
        how = "left",
        left_on = prt["Scheme Name"].astype(str).apply(lambda x: x.split("-")[0].strip()),
        right_on = "Scheme Name",
        suffixes=("","_df")
    ).drop(columns=["Scheme Name_df"])
)
t

# %%
import re
pattern  = re.compile("|".join(["- an.*","-an.*", r"\(an.*", r"\( an.*", r"\(.*\)", "as on.*", r"[^a-z0-9\- ]"] ))

# %%
d1 = set(prt["Scheme Name"].str.lower().unique())
d2 = set(df["Scheme Name"].str.lower().unique())

# %%
["" if not i else pattern.sub("", str(i)) for i in d1]
# Out:
# ['icici prudential smallcap fund',
#  'quant gilt fund',
#  'canara robeco corporate bond fund',
#  'sbi nifty 200 quality 30 etf',
#  'tata nifty500 multicap india manufacturing 50-30-20 index fund',
#  'aditya birla sun life low duration fund',
#  'icici prudential innovation fund',
#  'shriram flexi cap fund',
#  'aditya birla sun life balanced advantage fund',
#  'icici prudential rural opportunities fund',
#  'tata nifty india digital etf fund of fund',
#  'sbi long term advantage fund - series v',
#  'aditya birla sun life manufacturing equity fund',
#  '360 one elss tax saver nifty 50 index fund ',
#  'sundaram long term micro cap tax advantage fund series vi',
#  'dsp mid cap fund',
#  'nippon india etf bse sensex next 50 ',
#  'tata bse quality index fund',
#  'icici prudential nifty india consumption etf',
#  '360 one dynamic bond fund  ',
#  'nippon india floater fund ',
#  'sbi corporate bond fund',
#  'sbi elss tax saver fund',
#  'quant value fund',
# ...

# %%
import re
def clean(scheme_name):
    scheme_name = str(scheme_name)
    patterns  =  ["- an.*","-an.*", r"\(an.*", r"\( an.*", r"\([^)]*\)", "as on.*", "scheme having.*"]
    scheme_name = scheme_name.lower()
    for pattern in patterns:
        scheme_name = re.sub(pattern, "", scheme_name)
    scheme_name = re.sub( r"[^a-z0-9\- ]", " ", scheme_name)
    scheme_name = re.sub(r"\s+"," ",scheme_name)

    return scheme_name

# %%
clean("60:50 hello (max)  game")
# Out:
# '60 50 hello game'

# %%
[clean(i) for i in d1]
# Out:
# ['canara robeco equity hybrid fund',
#  'bank of india mid small cap equity debt fund ',
#  'canara robeco corporate bond fund',
#  'nippon india etf nifty bank bees ',
#  'icici prudential smallcap fund',
#  'canara robeco balanced advantage fund',
#  'tata nifty private bank exchange traded fund',
#  'pgim india corporate bond fund',
#  'hsbc nifty next 50 index fund',
#  'aditya birla sun life large mid cap fund',
#  'icici prudential equity minimum variance fund',
#  '',
#  'sbi infrastructure fund',
#  'quant dynamic asset allocation fund',
#  'jm value fund ',
#  'sbi nifty bank index fund',
#  'nippon india etf nifty 50 value 20 ',
#  'quant flexi cap fund',
#  'mirae asset arbitrage fund',
#  'dsp healthcare fund',
#  'quantum liquid fund ',
#  'sundaram infrastructure advantage fund',
#  'mirae asset bse select ipo etf',
#  'edel nifty alpha low volatility 30 index fund ',
#  'pgim india arbitrage fund',
#  'sundaram large cap fund',
# ...

# %% [markdown]
# ---
# Check ISIN Master

# %%
import pandas as pd
prt_data = pd.read_csv(r"Portfolio_extracted_091125-0440.csv")
isin_master = pd.read_excel(r"ISIN_master (2).xlsx",sheet_name="Combined ISIN List_Sel_Funds")

# %%
prt_data
# Out:
#                                       Name of Instrument          ISIN  \
# 0                       Embassy Office Parks REIT EOPR01  INE041025011
# 1                             Capital Infra Trust MEBP01  INE0Z8Z23013
# 2                    Brookfield India Real Estate Trust   INE0FDU25010
# 3                         Mindspace Business Parks REIT   INE0CCU25019
# 4      6.4% Jamnagar Utilities & Power Private Limite...  INE936D07174
# ...                                                  ...           ...
# 53473  ** 08.60 % SANSAR JAN 2025 TRUST - 25/10/2028 ^^   INE1WMT15017
# 53474  ** 08.20 % INDIA UNIVERSAL TRUST AL1 - 20/09/2...  INE16J715035
# 53475  ** 08.85 % SANSAR JUNE 2024 TRUST - 25/08/2027...  INE0YWN15017
# 53476  ** 08.17 % INDIA UNIVERSAL TRUST AL2 - 21/11/2...  INE1CBK15037
# 53477               SBIMF AIF - CAT I (CDMDF)27/10/2038   INF0RQ622028
#
#        Coupon        Industry      Quantity  Market Value  % to Net Assets  \
# ...

# %%
isin_master

INF579M0118,INF579M0119,INF579M0121,INF579M0124,INF579M0126,INF579M0129,INF579M0132,INF579M0120,INF579M0123,INF579M0122,INF579M0125,INF579M0128,INF579M0131
# Out:
#                                AMC          ISIN  \
# 0            360_ONE_MUTUALFUND_MF  INF579M01878
# 1            360_ONE_MUTUALFUND_MF  INF579M01183
# 2            360_ONE_MUTUALFUND_MF  INF579M01191
# 3            360_ONE_MUTUALFUND_MF  INF579M01191
# 4            360_ONE_MUTUALFUND_MF  INF579M01183
# ...                            ...           ...
# 2088           TAURUSMUTUALFUND_MF           NaN
# 2089            TRUSTMUTUALFUND_MF           NaN
# 2090            UNIONMUTUALFUND_MF           NaN
# 2091              UTIMUTUALFUND_MF           NaN
# 2092  WHITEOAKCAPITALMUTUALFUND_MF           NaN
#
#                                              SCHEME       VLOOKUP  Y/N
# 0         360 ONE FOCUSED FUND REGULAR PLAN- GROWTH  INF579M01878    Y
# 1                  360 ONE DYNAMIC BOND FUND-GROWTH  INF579M01183    Y
# 2                   360 ONE DYNAMIC BOND FUND-BONUS  INF579M01191    Y
# 3     360 ONE DYNAMIC BOND FUND REGULAR PLAN- BONUS  INF579M01191    Y
# ...

# %%
master_isins = isin_master["ISIN"].astype(str).unique()
master_isins
# Out:
# array(['INF579M01878', 'INF579M01183', 'INF579M01191', ...,
#        'INF03VN01126', 'WOC03VN01126', 'nan'], shape=(1892,), dtype=object)

# %%
available_isins = ",".join(prt_data["isin_group"].astype(str).unique())
available_isins
# Out:
# 'INF579M0118,INF579M0119,INF579M0121,INF579M0124,INF579M0126,INF579M0129,INF579M0132,INF579M0120,INF579M0123,INF579M0122,INF579M0125,INF579M0128,INF579M0131,INF579M0190,INF579M0191,INF579M0192,INF579M0187,INF579M0188,INF579M0189,INF579M0150,INF579M0151,INF579M0157,INF579M0156,INF579M0163,INF579M0169,INF579M0162,INF579M0168,INF579M01AG,INF579M01AH,INF579M01AF,INF579M01AI,INF579M01AJ,INF579M01AK,INF579M01AL,INF579M01AN,INF579M01AO,INF579M01AM,INF579M01AS,INF579M01AQ,INF579M01AR,INF579M01AT,INF579M01AU,INF579M01AP,nan,INF579M01BB,INF579M01BC,INF579M01BD,INF579M01BH,INF579M01BI,INF579M01BE,INF579M01BF,INF579M01BG,INF579M01BJ,INF579M01BN,INF579M01BO,INF579M01BM,INF579M01BK,INF579M01BL,INF209KC134,INF209KC136,INF209KC135,INF209KC133,INF209KB13D,INF209KB14D,INF209KB12D,INF209KB15D,INF209KC137,INF209KC138,INF209KC140,INF209KC139,INF209KB1U4,INF209KB1U5,INF209KB1U6,INF209KB1U7,INF209KB1U8,INF209KB1U9,INF209KB14J,INF209KB15J,INF209KB16J,INF209KB17J,INF209KB18J,INF209KB19J,INF209KB15R,INF209KB1
# ...

# %%
list(filter(lambda x : x in available_isins, master_isins))
# Out:
# ['nan']

# %%
"INF579SS1506" in available_isins.split(",")
# Out:
# False
